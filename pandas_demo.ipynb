# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
file_location =r"C:\Users\nasir\OneDrive\Desktop\SOS -CS18\Sample_data\survey_results_public-2022.csv"
df=pd.read_csv(file_location)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
#give the information about no. of rows and column
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
#used for print dispay 84 the column and 84 rows
pd.set_option('display.max_column', 84)    
pd.set_option('display.max_row', 84)

# %%
#used for display what is the meaning of column 
schema_df=pd.read_csv(r"C:\Users\nasir\OneDrive\Desktop\SOS -CS18\Sample_data\survey_results_schema_2019.csv")

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
#display only first 10 rows
df.head(10)
#dispaly only last 10 rows
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# ...

# %%
# Dictionary 
people= { "First":["Nasiruddin","Rohit","Sahil","sandipan"],
        "last":["Kabir","ahammed","Ahamed","Mandal"],
        "Email":["nasir@gamil.com","rohit@gamilcom","sahil@gamil.com","sandipa@gmail.com"]
}

# %%
import pandas as pd

# %%
df2=pd.DataFrame(people)

# %%
df2
# Out:
#         First     last              Email
# 0  Nasiruddin    Kabir    nasir@gamil.com
# 1       Rohit  ahammed     rohit@gamilcom
# 2       Sahil   Ahamed    sahil@gamil.com
# 3    sandipan   Mandal  sandipa@gmail.com

# %%
#access a column
df2['Email']
# Out:
# 0      nasir@gamil.com
# 1       rohit@gamilcom
# 2      sahil@gamil.com
# 3    sandipa@gmail.com
# Name: Email, dtype: object

# %%
#access a column
df2.Email
# Out:
# 0      nasir@gamil.com
# 1       rohit@gamilcom
# 2      sahil@gamil.com
# 3    sandipa@gmail.com
# Name: Email, dtype: object

# %%
df2[['last','Email']]
# Out:
#       last              Email
# 0    Kabir    nasir@gamil.com
# 1  ahammed     rohit@gamilcom
# 2   Ahamed    sahil@gamil.com
# 3   Mandal  sandipa@gmail.com

# %%
#Printing the column   it is a list
df2.columns
# Out:
# Index(['First', 'last', 'Email'], dtype='object')

# %%
#printing row we used loc or iloc
df2.iloc[0]
# Out:
# First         Nasiruddin
# last               Kabir
# Email    nasir@gamil.com
# Name: 0, dtype: object

# %%
#C

df2.iloc[[0,1],2]
#[0,1] repesent first 2 rows and 2 repesent the column 2 here it is "Email"
# Out:
# 0    nasir@gamil.com
# 1     rohit@gamilcom
# Name: Email, dtype: object

# %%
#printing a column with row using loc
df2.loc[[0,1],['Email','last']]
# Out:
#              Email     last
# 0  nasir@gamil.com    Kabir
# 1   rohit@gamilcom  ahammed

# %%
#for counting different type of thing in 'LearnCodeOnline' column
df['LearnCodeOnline'].value_counts()
# Out:
# LearnCodeOnline
# Technical documentation;Blogs;Written Tutorials;Stack Overflow                                                                                                                                         715
# Technical documentation;Blogs;Written Tutorials;Stack Overflow;Online forum                                                                                                                            706
# Technical documentation;Blogs;Stack Overflow                                                                                                                                                           589
# Technical documentation;Blogs;Written Tutorials;Stack Overflow;Online books;Online forum                                                                                                               530
# ...

# %%
#change a column to index but it not modified the data frame
df2.set_index('last')
# Out:
#               First              Email
# last
# Kabir    Nasiruddin    nasir@gamil.com
# ahammed       Rohit     rohit@gamilcom
# Ahamed        Sahil    sahil@gamil.com
# Mandal     sandipan  sandipa@gmail.com

# %%
#to modified the index
df2.set_index('last', inplace=True)
#we also apply another method to do this thing: 
                 # df=pd.read_csv('filename',index_col='column name')

# %%
df2
# Out:
#               First              Email
# last
# Kabir    Nasiruddin    nasir@gamil.com
# ahammed       Rohit     rohit@gamilcom
# Ahamed        Sahil    sahil@gamil.com
# Mandal     sandipan  sandipa@gmail.com

# %%
# To set the index in alphabatically order 
df2.sort_index(ascending=True,inplace=True)

# %%
df2
# Out:
#               First              Email
# last
# Ahamed        Sahil    sahil@gamil.com
# Kabir    Nasiruddin    nasir@gamil.com
# Mandal     sandipan  sandipa@gmail.com
# ahammed       Rohit     rohit@gamilcom

# %%
friend={"Frist":["Anawar","Hafiz","Arnab","Shartak"],
         "last":["Hossain","Hossain","Ghosh","Pal"],
           "Age":["20","20.5","19","19.5"],
          "Exam":["50%","99%","20%","5%"] }

# %%
d3f=pd.DataFrame(friend)

# %%
d3f
# Out:
#      Frist     last   Age Exam
# 0   Anawar  Hossain    20  50%
# 1    Hafiz  Hossain  20.5  99%
# 2    Arnab    Ghosh    19  20%
# 3  Shartak      Pal  19.5   5%

# %%
d3f['last']=='Hossain'
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: last, dtype: bool

# %%
#To filter something
filt=(d3f['last']=='Hossain')

# %%
#which gives true they are filter out---->PASSING BOOL
d3f[filt]
# Out:
#     Frist     last   Age Exam
# 0  Anawar  Hossain    20  50%
# 1   Hafiz  Hossain  20.5  99%

# %%
#passing multiple filter --------> USE OR ,AND
fil=(d3f['last']=='Hossain') & ( d3f['Frist']=='Anawar')

# %%
d3f[fil]
# Out:
#     Frist     last Age Exam
# 0  Anawar  Hossain  20  50%

# %%
df4=pd.read_csv(r"C:\Users\nasir\OneDrive\Desktop\SOS -CS18\Sample_data\survey_results_public_2019.csv")

# %%
df4
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#filter out by country name 
countries=['United States','India','Germany','Canada']
fit=df4['Country'].isin(countries)

# %%
#checking is the string is present on not
df4['LanguageWorkedWith'].str.contains('Python',na=False)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
d3f.columns=["Frist Name","Last Name","Age","Selection Probality"]

# %%
d3f
# Out:
#   Frist Name Last Name   Age Selection Probality
# 0     Anawar   Hossain    20                 50%
# 1      Hafiz   Hossain  20.5                 99%
# 2      Arnab     Ghosh    19                 20%
# 3    Shartak       Pal  19.5                  5%

# %%
#To change all the column name into upper case
d3f.columns = [x.upper() for x in d3f.columns]
d3f
# Out:
#   FRIST NAME LAST NAME   AGE SELECTION PROBALITY
# 0     Anawar   Hossain    20                 50%
# 1      Hafiz   Hossain  20.5                 99%
# 2      Arnab     Ghosh    19                 20%
# 3    Shartak       Pal  19.5                  5%

# %%
#to replace something
d3f.columns= d3f.columns.str.replace(' ','_')

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY
# 0     Anawar   Hossain    20                 50%
# 1      Hafiz   Hossain  20.5                 99%
# 2      Arnab     Ghosh    19                 20%
# 3    Shartak       Pal  19.5                  5%

# %%
#To update a full row by scicific data 
d3f.loc[1]=['Hafiz','Ali','20','98.9%']

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY
# 0     Anawar   Hossain    20                 50%
# 1      Hafiz       Ali    20               98.9%
# 2      Arnab     Ghosh    19                 20%
# 3    Shartak       Pal  19.5                  5%

# %%
#To update a element / 2 element of row [1] is the row
d3f.loc[[1],['Last Name','Age']]=['Ahammed','20.5']
# Out:
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\722850483.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Ahammed' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   d3f.loc[[1],['Last Name','Age']]=['Ahammed','20.5']
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\722850483.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   d3f.loc[[1],['Last Name','Age']]=['Ahammed','20.5']

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY Last Name   Age
# 0     Anawar   Hossain    20                 50%       NaN   NaN
# 1      Hafiz       Ali    20               98.9%   Ahammed  20.5
# 2      Arnab     Ghosh    19                 20%       NaN   NaN
# 3    Shartak       Pal  19.5                  5%       NaN   NaN

# %%
# to change a whole column into lower case
d3f['Frist_Name']=d3f['Frist'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frist'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 2
#       1 # to change a whole column into lower case
# ...

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY Last Name   Age
# 0     Anawar   Hossain    20                 50%       NaN   NaN
# 1      Hafiz       Ali    20               98.9%   Ahammed  20.5
# 2      Arnab     Ghosh    19                 20%       NaN   NaN
# 3    Shartak       Pal  19.5                  5%       NaN   NaN

# %%
# "apply" method 
def update_email(email):
    return email.upper()
## here we apply the function to this email
df2['Email'].apply(update_email)
# Out:
# last
# Ahamed       SAHIL@GAMIL.COM
# Kabir        NASIR@GAMIL.COM
# Mandal     SANDIPA@GMAIL.COM
# ahammed       ROHIT@GAMILCOM
# Name: Email, dtype: object

# %%
#in above we have apply index as lasrt name 
df2['Email'].apply(len)
# Out:
# last
# Ahamed     15
# Kabir      15
# Mandal     17
# ahammed    14
# Name: Email, dtype: int64

# %%
#To apply in all the element in the data frame we use applymap
d3f.applymap(len)
# Out:
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\3803962375.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   d3f.applymap(len)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 2
#       1 #To apply in all the element in the data frame we use applymap
# ----> 2 d3f.applymap(len)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:10495, in DataFrame.applymap(self, func, na_action, **kwargs)
#   10446 """
#   10447 Apply a function to a Dataframe elementwise.
#   10448
#    (...)
#   10488 1  5  5
#   10489 """
#   10490 warnings.warn(
#   10491     "DataFrame.applymap has been deprecated. Use DataFrame.map instead.",
#   10492     FutureWarning,
#   10493     stacklevel=find_stack_level(),
#   10494 )
# > 10495 return self.map(func, na_action=na_action, **kwargs)
#
# ...

# %%
#to rename a column or a element
d3f.rename(columns={"Frist":"Frist_Name"},inplace=True)
d3f
# Out:
#   Frist_Name Last_Name   Age Selection_Probality Last Name
# 0     Anawar   Hossain    20                 50%       NaN
# 1      Hafiz       Ali  20.5               98.9%   Ahammed
# 2      Arnab     Ghosh    19                 20%       NaN
# 3    Shartak       Pal  19.5                  5%       NaN

# %%
df4['Hobbyist'].map({'Yes':'Y','No':'N'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df4['Hobbyist'].map({'Yes':'Y','No':'N'})
#
# NameError: name 'df4' is not defined

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY Last Name   Age
# 0     Anawar   Hossain    20                 50%       NaN   NaN
# 1      Hafiz       Ali    20               98.9%   Ahammed  20.5
# 2      Arnab     Ghosh    19                 20%       NaN   NaN
# 3    Shartak       Pal  19.5                  5%       NaN   NaN

# %%
# To Joining the first name and last name and append in Data frame 
d3f['Full Name']=d3f['Frist Name'] + ' ' +d3f['Last Name']
d3f
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frist Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 2
# ...

# %%
d3f.rename(columns={'Frist Name':'Frist','Last Name':'Last','Full Name':'Name'},inplace=True)
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age
# 0     Anawar   Hossain    20                 50%      NaN   NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5
# 2      Arnab     Ghosh    19                 20%      NaN   NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN

# %%
#Drop a colummn 
d3f.drop(columns=['Frist','Last'])  # use inplace= True to replace it permanently
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 2
#       1 #Drop a colummn
# ----> 2 d3f.drop(columns=['Frist','Last'])  # use inplace= True to replace it permanently
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
# To split a string
d3f['Name'].str.split(' ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 2
#       1 # To split a string
# ----> 2 d3f['Name'].str.split(' ')
# ...

# %%
# TO expand a column 
d3f[["F_Name","L_Name"]]=d3f["Name"].str.split(' ',expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 # TO expand a column
# ...

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age
# 0     Anawar   Hossain    20                 50%      NaN   NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5
# 2      Arnab     Ghosh    19                 20%      NaN   NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN

# %%
#To append some thing a New column
new_insert={'Frist':['Nasir'],'Age':['20'] }
d_insert=pd.DataFrame(new_insert)
d3f=pd.concat([d3f,d_insert],ignore_index=True)   # we USe ignore_index=True because there are some missing data
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age  Frist
# 0     Anawar   Hossain    20                 50%      NaN   NaN    NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5    NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN    NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN    NaN
# 4        NaN       NaN   NaN                 NaN      NaN    20  Nasir

# %%
people_4={"Frist":["Tony","steven"],
     "Last": ["Stark","Roger"]    
}
df5=pd.DataFrame(people_4)
df5
# Out:
#     Frist   Last
# 0    Tony  Stark
# 1  steven  Roger

# %%
# Concat another dataframe with d3f
d3f = pd.concat([d3f, df5], ignore_index=True)

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age   Frist
# 0     Anawar   Hossain    20                 50%      NaN   NaN     NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5     NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN     NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN     NaN
# 4        NaN       NaN   NaN                 NaN      NaN    20   Nasir
# 5        NaN       NaN   NaN                 NaN    Stark   NaN    Tony
# 6        NaN       NaN   NaN                 NaN    Roger   NaN  steven

# %%
# Drop a index
d3f.drop(index=6,inplace=True)

# %%
d3f
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age  Frist
# 0     Anawar   Hossain    20                 50%      NaN   NaN    NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5    NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN    NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN    NaN
# 4        NaN       NaN   NaN                 NaN      NaN    20  Nasir
# 5        NaN       NaN   NaN                 NaN    Stark   NaN   Tony

# %%
#Drop by condn
d3f.drop(index=d3f[d3f['Last']=='Pal'].index)
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age  Frist
# 0     Anawar   Hossain    20                 50%      NaN   NaN    NaN
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5    NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN    NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN    NaN
# 4        NaN       NaN   NaN                 NaN      NaN    20  Nasir
# 5        NaN       NaN   NaN                 NaN    Stark   NaN   Tony

# %%
#sorting
d3f.sort_values(by='Last',ascending=True)
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age  Frist
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5    NaN
# 5        NaN       NaN   NaN                 NaN    Stark   NaN   Tony
# 0     Anawar   Hossain    20                 50%      NaN   NaN    NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN    NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN    NaN
# 4        NaN       NaN   NaN                 NaN      NaN    20  Nasir

# %%
# sorting by using two condition
d3f.sort_values(by=["Last","Frist"],ascending=[True,True])    # Give more priority to the which writen frist in the list
# Out:
#   FRIST_NAME LAST_NAME   AGE SELECTION_PROBALITY     Last   Age  Frist
# 1      Hafiz       Ali    20               98.9%  Ahammed  20.5    NaN
# 5        NaN       NaN   NaN                 NaN    Stark   NaN   Tony
# 4        NaN       NaN   NaN                 NaN      NaN    20  Nasir
# 0     Anawar   Hossain    20                 50%      NaN   NaN    NaN
# 2      Arnab     Ghosh    19                 20%      NaN   NaN    NaN
# 3    Shartak       Pal  19.5                  5%      NaN   NaN    NaN

# %%
df4.sort_values(by=['ConvertedComp','Country'],ascending=[False,True],inplace=True)
df4[['Country','ConvertedComp']].head(50)
# Out:
#               Country  ConvertedComp
# 25833          Canada      2000000.0
# 87353         Germany      2000000.0
# 21895           India      2000000.0
# 28080           India      2000000.0
# 72274           India      2000000.0
# 77665          Mexico      2000000.0
# 79701     Netherlands      2000000.0
# 51798            Peru      2000000.0
# 75088       Singapore      2000000.0
# 32056     Switzerland      2000000.0
# 83866  United Kingdom      2000000.0
# 57      United States      2000000.0
# 101     United States      2000000.0
# 164     United States      2000000.0
# 434     United States      2000000.0
# 450     United States      2000000.0
# 489     United States      2000000.0
# 537     United States      2000000.0
# 767     United States      2000000.0
# 786     United States      2000000.0
# 1228    United States      2000000.0
# 1374    United States      2000000.0
# 1375    United States      2000000.0
# 1404    United States      2000000.0
# ...

# %%
# Find 10 largest value among the columns
df4['ConvertedComp'].nlargest(10)

## df.nleargest(10,'ConvertedComp')
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
# Finding mean/median/ mode
df4["ConvertedComp"].median()
# Out:
# 57287.0

# %%
lis=['ConvertedComp','CompTotal','WorkWeekHrs','CodeRevHrs','Age']

# %%
# To define the stastic of the following columns
df4[lis].describe()
# Out:
#        ConvertedComp     CompTotal   WorkWeekHrs    CodeRevHrs           Age
# count   5.582300e+04  5.594500e+04  64503.000000  49790.000000  79210.000000
# mean    1.271107e+05  5.519014e+11     42.127197      5.084308     30.336699
# std     2.841523e+05  7.331926e+13     37.287610      5.513931      9.178390
# min     0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%     2.577750e+04  2.000000e+04     40.000000      2.000000     24.000000
# 50%     5.728700e+04  6.200000e+04     40.000000      4.000000     29.000000
# 75%     1.000000e+05  1.200000e+05     44.750000      6.000000     35.000000
# max     2.000000e+06  1.000000e+16   4850.000000     99.000000     99.000000

# %%
#to watch no. of column contained the value
df4['ConvertedComp'].count()
# Out:
# 55823

# %%
# To find the distribution of the columns
df4["Hobbyist"].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
filt1=df4["Country"]=='India'
df4.loc[filt1]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 16703       16793                     I am a developer by profession      Yes
# 52225       52561                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88808       77339                                                NaN      Yes
# 88825       79795                                                NaN      Yes
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88864       86012                                                NaN      Yes
#
# ...

# %%
#filter used to watch a single col
df4.loc[filt1]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
# Group a column by its country name 
country_group=df4.groupby('Country')   # divided into different group
India_Grp=country_group.get_group('India')   # Access the group 

India_Grp.head(5)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 16703       16793                     I am a developer by profession      Yes
# 52225       52561                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 21895                                              Never
# 28080                         Once a month or more often
# 72274  Less than once a month but more than once per ...
# 16703                         Once a month or more often
# 52225                                              Never
#
#                                               OpenSource  \
# 21895  The quality of OSS and closed source software ...
# ...

# %%
# Aggergated Item of stastics
country_group["ConvertedComp"].agg(['median','mean']).loc['Inda']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Inda'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Aggergated Item of stastics
# ...

# %%
# filtering out the total % of people from each country know python
               # mini Project
def count_python_occurrences(language_series):
    return language_series.str.contains('Python').sum()

result = country_group['LanguageWorkedWith'].apply(count_python_occurrences)
result
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
def count_python_occurrences(language_series):
    return language_series.str.contains('Python').sum()

total_result = country_group['LanguageWorkedWith'].apply(count_python_occurrences)
result
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
total_Respones=df4['Country'].value_counts()

# %%
#concating both above output into a data frame
per_df=pd.concat([total_Respones,total_result],axis="columns",sort=False)

# %%
per_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# Niger                                 1                   1
# Timor-Leste                           1                   1
# Chad                                  1                   0
# Saint Vincent and the Grenadines      1                   0
# Tonga                                 1                   0
#
# [179 rows x 2 columns]

# %%
per_df["%_Know python"]=(per_df['LanguageWorkedWith']/per_df['count'])*100

# %%
per_df
# Out:
#                                   count  LanguageWorkedWith  %_Know python
# Country
# United States                     20949               10083      48.131176
# India                              9061                3105      34.267741
# Germany                            5866                2451      41.783157
# United Kingdom                     5737                2384      41.554820
# Canada                             3395                1558      45.891016
# ...                                 ...                 ...            ...
# Niger                                 1                   1     100.000000
# Timor-Leste                           1                   1     100.000000
# Chad                                  1                   0       0.000000
# Saint Vincent and the Grenadines      1                   0       0.000000
# Tonga                                 1                   0       0.000000
#
# [179 rows x 3 columns]

# %%
                #Data cleaning
import numpy as np
people_clean = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df_c=pd.DataFrame(people_clean)
df_c
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# Relpace "NA" string into NaN
df_c.replace('NA',np.nan,inplace=True)
df_c.replace('Missing',np.nan,inplace=True)

# %%
# data cleaning 
# To finding the unique No.of enteries in a colum
df4['YearsCode'].unique()
# Out:
# array(['8', '9', '3', '25', '4', '15', '26', '19', '16', '43', '28', '7',
#        '20', '22', '5', '12', '2', '6', '13', '11', '24', '30', '14',
#        '17', '35', '18', '10', '1', '38', '21', '40', '39', nan, '29',
#        '23', '42', '31', 'Less than 1 year', '34', '27', '33', '36', '37',
#        '32', '45', '44', '46', '41', 'More than 50 years', '49', '50',
#        '47', '48'], dtype=object)

# %%
df4['YearsCode'].replace('More than 50 years',0,inplace=True)
# Out:
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\2665292677.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4['YearsCode'].replace('More than 50 years',0,inplace=True)

# %%
df4['YearsCode'].replace('Less than 1 year', 51, inplace=True)
# Out:
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\884647057.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4['YearsCode'].replace('Less than 1 year', 51, inplace=True)

# %%
df4['YearsCode']=df4['YearsCode'].astype(float)

# %%
means=df4['YearsCode'].mean()

# %%
df4['YearsCode'].replace(np.nan,means,inplace=True)
# Out:
# C:\Users\nasir\AppData\Local\Temp\ipykernel_11884\3396043882.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4['YearsCode'].replace(np.nan,means,inplace=True)

# %%
df4['YearsCode']
# Out:
# 25833     8.000000
# 87353     9.000000
# 21895     3.000000
# 28080    25.000000
# 72274     4.000000
#            ...
# 88873    12.381837
# 88874    12.381837
# 88879    12.381837
# 88880    12.381837
# 88881    12.381837
# Name: YearsCode, Length: 88883, dtype: float64
